# %%
import pandas as pd
import datetime 
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
pip install Plotly pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
path = ('C:\Python\Data\VINAMILK\source')
data = pd.read_csv(path +'\data_VNM.csv')
data
# Out:
#            Ngày  Tổng KLGD  Tổng GTGD  Vốn hóa TT  Đóng cửa  +/- giá  \
# 0    2022-10-14  1746000.0   129450.0    154657.0   74000.0    200.0
# 1    2022-10-13  3171000.0   229903.0    154239.0   73800.0   2200.0
# 2    2022-10-12  1274000.0    90738.0    149641.0   71600.0   1400.0
# 3    2022-10-11  1718400.0   120962.0    146715.0   70200.0   -300.0
# 4    2022-10-10  1661900.0   116323.0    147342.0   70500.0    700.0
# ..          ...        ...        ...         ...       ...      ...
# 244  2021-10-22  4510000.0   405938.0    189141.0   90500.0   1400.0
# 245  2021-10-21  4036500.0   361928.0    186215.0   89100.0   -900.0
# 246  2021-10-20  5975224.0   538749.0    188096.0   90000.0   -300.0
# 247  2021-10-19  7011854.0   631982.0    188723.0   90300.0    500.0
# 248  2021-10-18  3173092.0   284493.0    187678.0   89800.0   -200.0
#
#      +/- % giá         KL        GT
# 0         0.27  1436500.0  106504.0
# 1         3.07  3171000.0  229903.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ngày        249 non-null    object
#  1   Tổng KLGD   249 non-null    float64
#  2   Tổng GTGD   249 non-null    float64
#  3   Vốn hóa TT  249 non-null    float64
#  4   Đóng cửa    249 non-null    float64
#  5   +/- giá     234 non-null    float64
#  6   +/- % giá   234 non-null    float64
#  7   KL          249 non-null    float64
#  8   GT          249 non-null    float64
#  9   ma_1        243 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 19.6+ KB

# %%
data.describe()
# Out:
#           Tổng KLGD      Tổng GTGD     Vốn hóa TT      Đóng cửa      +/- giá  \
# count  2.490000e+02     249.000000     249.000000    249.000000   234.000000
# mean   2.579470e+06  203186.208835  162716.967871  77857.028112   -51.709402
# std    1.197135e+06  102908.518029   13998.792327   6698.817361  1205.360552
# min    9.654000e+05   79134.000000  134802.000000  64500.000000 -3100.000000
# 25%    1.776300e+06  136750.000000  151522.000000  72500.000000  -800.000000
# 50%    2.339100e+06  178288.000000  159046.000000  76100.000000  -200.000000
# 75%    3.078600e+06  243488.000000  174511.000000  83500.000000   500.000000
# max    9.645800e+06  761706.000000  189768.000000  90800.000000  4700.000000
#
#         +/- % giá            KL             GT          ma_1         sma_1  \
# count  234.000000  2.490000e+02     249.000000    245.000000    245.000000
# mean    -0.048462  2.368116e+06  186285.413655  77797.551020  77797.551020
# ...

# %%
ma1=5
data['sma_1']=data['Đóng cửa'].rolling(window=ma1).mean()
data['stma_1']=data['Đóng cửa'].rolling(window=ma1).std()
del data['ma_1']
data.head(30)
# Out:
#           Ngày  Tổng KLGD  Tổng GTGD  Vốn hóa TT  Đóng cửa  +/- giá  \
# 0   2022-10-14  1746000.0   129450.0    154657.0   74000.0    200.0
# 1   2022-10-13  3171000.0   229903.0    154239.0   73800.0   2200.0
# 2   2022-10-12  1274000.0    90738.0    149641.0   71600.0   1400.0
# 3   2022-10-11  1718400.0   120962.0    146715.0   70200.0   -300.0
# 4   2022-10-10  1661900.0   116323.0    147342.0   70500.0    700.0
# 5   2022-10-07  2685300.0   182976.0    145879.0   69800.0   -200.0
# 6   2022-10-06  1819500.0   128822.0    146297.0   70000.0  -1600.0
# 7   2022-10-05  1493400.0   106914.0    149641.0   71600.0    700.0
# 8   2022-10-04  1755300.0   124331.0    148178.0   70900.0   -100.0
# 9   2022-10-03  2339100.0   168449.0    148387.0   71000.0  -1300.0
# 10  2022-09-30  2509400.0   181799.0    151104.0   72300.0   -400.0
# 11  2022-09-29  2375100.0   173321.0    151940.0   72700.0    900.0
# 12  2022-09-28  2492400.0   179064.0    150059.0   71800.0   -600.0
# ...

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data['YEARS'] = data['DATE'].str[6:10]
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/User/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a> try:
# -> <a href='file:///c%3A/Users/User/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3628'>3629</a>     return self._engine.get_loc(casted_key)
# ...

# %%
data_value = data.groupby('YEARS').max()['HIGH']
data_value
# Out:
# YEARS
# 2012     91.4254
# 2013    151.0000
# 2014    150.0000
# 2015    140.0000
# 2016    175.0000
# 2017    205.5000
# 2018    215.0000
# 2019    152.6000
# Name: HIGH, dtype: float64

# %%
data_value1 = data.groupby('YEARS').max()['VOLUME']
data_value1
# Out:
# YEARS
# 2012     504420
# 2013    2920100
# 2014     540090
# 2015     256707
# 2016     662463
# 2017     449514
# 2018     233726
# 2019     207022
# Name: VOLUME, dtype: int64

# %%
px.line(data, y= ['KL','GT'],x='Ngày',title='VINAMILK')

# %%
px.line(data, y= ['HIGH','LOW'],x='DATE',title='VINAMILK')

# %%
px.line(data, y= 'Đóng cửa',x='Ngày')

# %%
px.line(data, y= 'ma_1',x='Ngày')

# %%
px.line(data, y= 'Đóng cửa',x='Ngày')

# %%
px.line(data, y= ['KL','GT','Đóng cửa','+/- % giá','+/- giá','Vốn hóa TT','Tổng GTGD','Tổng KLGD'],x='Ngày')

# %%
data.head()
# Out:
#          Ngày  Tổng KLGD  Tổng GTGD  Vốn hóa TT  Đóng cửa  +/- giá  +/- % giá  \
# 0  2022-10-14  1746000.0   129450.0    154657.0   74000.0    200.0       0.27
# 1  2022-10-13  3171000.0   229903.0    154239.0   73800.0   2200.0       3.07
# 2  2022-10-12  1274000.0    90738.0    149641.0   71600.0   1400.0       1.99
# 3  2022-10-11  1718400.0   120962.0    146715.0   70200.0   -300.0      -0.43
# 4  2022-10-10  1661900.0   116323.0    147342.0   70500.0    700.0       1.00
#
#           KL        GT
# 0  1436500.0  106504.0
# 1  3171000.0  229903.0
# 2  1274000.0   90738.0
# 3  1718400.0  120962.0
# 4  1661900.0  116323.0

# %%
data['Tháng'] = data['Ngày'].str[5:7]
data['Năm'] = data['Ngày'].str[0:4]
data
# Out:
#            Ngày  Tổng KLGD  Tổng GTGD  Vốn hóa TT  Đóng cửa  +/- giá  \
# 0    2022-10-14  1746000.0   129450.0    154657.0   74000.0    200.0
# 1    2022-10-13  3171000.0   229903.0    154239.0   73800.0   2200.0
# 2    2022-10-12  1274000.0    90738.0    149641.0   71600.0   1400.0
# 3    2022-10-11  1718400.0   120962.0    146715.0   70200.0   -300.0
# 4    2022-10-10  1661900.0   116323.0    147342.0   70500.0    700.0
# ..          ...        ...        ...         ...       ...      ...
# 244  2021-10-22  4510000.0   405938.0    189141.0   90500.0   1400.0
# 245  2021-10-21  4036500.0   361928.0    186215.0   89100.0   -900.0
# 246  2021-10-20  5975224.0   538749.0    188096.0   90000.0   -300.0
# 247  2021-10-19  7011854.0   631982.0    188723.0   90300.0    500.0
# 248  2021-10-18  3173092.0   284493.0    187678.0   89800.0   -200.0
#
#      +/- % giá         KL        GT Tháng   Năm
# 0         0.27  1436500.0  106504.0     10  2022
# ...

# %%
data_value = data.groupby('Năm').min()['Đóng cửa']
data_value
# Out:
# Năm
# 2021    84700.0
# 2022    64500.0
# Name: Đóng cửa, dtype: float64

# %%
data
# Out:
#            Ngày  Tổng KLGD  Tổng GTGD  Vốn hóa TT  Đóng cửa  +/- giá  \
# 0    2022-10-14  1746000.0   129450.0    154657.0   74000.0    200.0
# 1    2022-10-13  3171000.0   229903.0    154239.0   73800.0   2200.0
# 2    2022-10-12  1274000.0    90738.0    149641.0   71600.0   1400.0
# 3    2022-10-11  1718400.0   120962.0    146715.0   70200.0   -300.0
# 4    2022-10-10  1661900.0   116323.0    147342.0   70500.0    700.0
# ..          ...        ...        ...         ...       ...      ...
# 244  2021-10-22  4510000.0   405938.0    189141.0   90500.0   1400.0
# 245  2021-10-21  4036500.0   361928.0    186215.0   89100.0   -900.0
# 246  2021-10-20  5975224.0   538749.0    188096.0   90000.0   -300.0
# 247  2021-10-19  7011854.0   631982.0    188723.0   90300.0    500.0
# 248  2021-10-18  3173092.0   284493.0    187678.0   89800.0   -200.0
#
#      +/- % giá         KL        GT Tháng   Năm
# 0         0.27  1436500.0  106504.0     10  2022
# ...

# %%
data['Ngày']=pd.to_datetime(data['Ngày'])

# %%
data['Đóng cửa'] = pd.to_numeric(data['Đóng cửa'],downcast='integer')

# %%
print(data['KL'].dtypes)
# Out:
# float64

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['GT']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Giá Trị')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['KL']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Khối lượng')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['+/- % giá']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('+/- % giá')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['+/- giá']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Giá Tăng/Giảm')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['Đóng cửa']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['Vốn hóa TT']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Vốn hóa TT')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['Tổng GTGD']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Tổng GTGD')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.grid()
days = data['Ngày']
Values=data['Tổng KLGD']
plt.plot(days,Values)
plt.xticks(days, rotation=45, size =3)
plt.xlabel('Thời gian')
plt.ylabel('Tổng KL giao dịch')
plt.show()

# %%
dfday=pd.to_datetime(data['Ngày'],errors='ignore') 
dfday
# Out:
# 0     2022-10-14
# 1     2022-10-13
# 2     2022-10-12
# 3     2022-10-11
# 4     2022-10-10
#          ...
# 244   2021-10-22
# 245   2021-10-21
# 246   2021-10-20
# 247   2021-10-19
# 248   2021-10-18
# Name: Ngày, Length: 249, dtype: datetime64[ns]

# %%
data_value.max()
# Out:
# 84700.0

# %%
print(set(data['Tháng']))
# Out:
# {'02', '10', '08', '06', '03', '01', '09', '12', '04', '05', '07', '11'}
